# %% [markdown]
# <h1 style= 'text-align : center '> PROJECT I: WINE PRODUCTION </h1>

# %% [markdown]
# ## ID : 10958118
# ## FULL NAME: QUARCOO AHIMA RABIATU
# ## DEPARTMENT: MATERIAL SCIENCE AND ENGINEEERING

# %% [markdown]
# ---

# %% [markdown]
# <h2 style ='text-align:center'> TABLE OF CONTENT</h2>

# %% [markdown]
# ---

# %% [markdown]
# ### INTRODUCTION
# ### 1- PRE PROCESSING OF THE DATA
# ### 2- STATISTICAL INFERENCES OF THE ENTIRE DATA
# ### 3- STATISTICAL INFERENCES OF EACH FEATURES OF THE DATA SET
# ###  CONCLUSION

# %% [markdown]
# ---

# %% [markdown]
# #### INTRODUCTION

# %% [markdown]
# Data analysis of red wine company

# %%
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("data.csv")

# %%
data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 2        3            7.8             0.760         0.04             2.3
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulphur_dioxide  total_sulphur_dioxide  density    pH  \
# ...

# %% [markdown]
# ### 1- PRE PROCESSING OF THE DATA

# %% [markdown]
# * CHECKING FOR NULL DATA

# %%
data.isnull().any().any()
# Out:
# True

# %% [markdown]
# * After checking we can notice that there is null data

# %% [markdown]
# * Checking for duplicates

# %%
data.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 1596    False
# 1597    False
# 1598    False
# 1599    False
# 1600    False
# Length: 1601, dtype: bool

# %% [markdown]
# There are no duplicats in the Dataset.

# %% [markdown]
# * Removing the null value with dropna() method

# %% [markdown]
# this method is been used the fact that the null are not considerable

# %%
new_data= data.dropna()

# %%
new_data
# Out:
#         ID  fixed_acidity  volatile_acidity  citric_acid  residual_sugar  \
# 0        1            7.4             0.700         0.00             1.9
# 1        2            7.8             0.880         0.00             2.6
# 3        4           11.2             0.280         0.56             1.9
# 4        5            7.4             0.700         0.00             1.9
# 5        6            7.4             0.660         0.00             1.8
# ...    ...            ...               ...          ...             ...
# 1596  1597            5.9             0.550         0.10             2.2
# 1597  1598            6.3             0.510         0.13             2.3
# 1598  1599            5.9             0.645         0.12             2.0
# 1599  1600            6.0             0.310         0.47             3.6
# 1600  1601            7.2             0.390         0.44             2.6
#
#       chlorides  free_sulphur_dioxide  total_sulphur_dioxide  density    pH  \
# ...

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1591 entries, 0 to 1600
# Data columns (total 13 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   ID                     1591 non-null   int64
#  1   fixed_acidity          1591 non-null   float64
#  2   volatile_acidity       1591 non-null   float64
#  3   citric_acid            1591 non-null   float64
#  4   residual_sugar         1591 non-null   float64
#  5   chlorides              1591 non-null   float64
#  6   free_sulphur_dioxide   1591 non-null   float64
#  7   total_sulphur_dioxide  1591 non-null   float64
#  8   density                1591 non-null   float64
#  9   pH                     1591 non-null   float64
#  10  sulphates              1591 non-null   float64
#  11  alcohol                1591 non-null   float64
#  12  quality                1591 non-null   float64
# dtypes: float64(12), int64(1)
# memory usage: 174.0 KB

# %%
new_data.shape
# Out:
# (1591, 13)

# %% [markdown]
# ### 2- STATISTICAL INFERENCES OF THE INTER DATA

# %% [markdown]
# * the data set after pre processing - New data set

# %%
new_data.describe()
# Out:
#                 ID  fixed_acidity  volatile_acidity  citric_acid  \
# count  1591.000000    1591.000000       1591.000000  1591.000000
# mean    801.060968       8.320616          0.527681     0.271477
# std     460.740942       1.740134          0.179045     0.194807
# min       1.000000       4.600000          0.120000     0.000000
# 25%     402.500000       7.100000          0.390000     0.090000
# 50%     801.000000       7.900000          0.520000     0.260000
# 75%    1199.500000       9.200000          0.640000     0.420000
# max    1601.000000      15.900000          1.580000     1.000000
#
#        residual_sugar    chlorides  free_sulphur_dioxide  \
# count     1591.000000  1591.000000           1591.000000
# mean         2.540761     0.087500             15.861722
# std          1.413076     0.047175             10.429385
# min          0.900000     0.012000              1.000000
# 25%          1.900000     0.070000              7.000000
# ...

# %%
data= data.loc[0:1501, ['fixed_acidity','volatile_acidity','citric_acid','residual_sugar','chlorides', 'free_sulphur_dioxide','total_sulphur_dioxide','density','pH','sulphates','alcohol','quality']]

# %%
plt.figure(figsize= (5,5) ,dpi= 300)
sns.histplot(data= data, bins= 20, binwidth= 10, element= 'poly')
# Out:
# <Axes: ylabel='Count'>

# %%
plt.figure(figsize= (13,5) ,dpi= 300)
sns.scatterplot(data= data, palette = 'Dark2')
# Out:
# <Axes: >

# %% [markdown]
# ### 3- STATISTICAL INFERENCES OF EACH FEATURES

# %%
new_data['fixed_acidity'].describe()
# Out:
# count    1591.000000
# mean        8.320616
# std         1.740134
# min         4.600000
# 25%         7.100000
# 50%         7.900000
# 75%         9.200000
# max        15.900000
# Name: fixed_acidity, dtype: float64

# %%
a= new_data['fixed_acidity']< new_data['fixed_acidity'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23631230250>,
# ...
#  [Text(-0.3613292813211187, 1.0389615731392399, ''),
#   Text(0.3613291840465145, -1.0389616069693242, '')],
#  [Text(-0.19708869890242836, 0.5667063126214035, '60.654%'),
#   Text(0.19708864584355332, -0.5667063310741767, '39.346%')])

# %%
b= new_data['volatile_acidity']< new_data['volatile_acidity'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x236312b0250>,
# ...
#  [Text(-0.3613292813211187, 1.0389615731392399, ''),
#   Text(0.3613291840465145, -1.0389616069693242, '')],
#  [Text(-0.19708869890242836, 0.5667063126214035, '60.654%'),
#   Text(0.19708864584355332, -0.5667063310741767, '39.346%')])

# %%
a= new_data['citric_acid']< new_data['citric_acid'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x236312c3350>,
# ...
#  [Text(-0.11166845075015946, 1.0943172104591334, ''),
#   Text(0.11166834829278681, -1.0943172209142837, '')],
#  [Text(-0.06091006404554152, 0.5969002966140727, '53.237%'),
#   Text(0.06091000815970189, -0.596900302316882, '46.763%')])

# %%
a= new_data['residual_sugar']< new_data['residual_sugar'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x236315cc5d0>,
# ...
#  [Text(-0.7185543843468147, 0.8328742982803409, ''),
#   Text(0.7185543843468151, -0.8328742982803405, '')],
#  [Text(-0.39193875509826254, 0.4542950717892768, '72.659%'),
#   Text(0.3919387550982627, -0.4542950717892766, '27.341%')])

# %%
a= new_data['chlorides']< new_data['chlorides'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23631647d90>,
# ...
#  [Text(-0.6575840190878368, 0.8818068143535112, ''),
#   Text(0.6575840190878364, -0.8818068143535115, '')],
#  [Text(-0.35868219222972914, 0.4809855351019151, '70.396%'),
#   Text(0.35868219222972886, -0.48098553510191533, '29.604%')])

# %%
a= new_data['free_sulphur_dioxide']< new_data['free_sulphur_dioxide'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x236316c9b90>,
# ...
#  [Text(-0.26349060057767765, 1.0679759844711936, ''),
#   Text(0.2634906005776775, -1.0679759844711936, '')],
#  [Text(-0.14372214576964232, 0.5825323551661055, '57.700%'),
#   Text(0.14372214576964226, -0.5825323551661055, '42.300%')])

# %%
a= new_data['total_sulphur_dioxide']< new_data['total_sulphur_dioxide'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23631740350>,
# ...
#  [Text(-0.37361295682946566, 1.0346078283529194, ''),
#   Text(0.373612956829466, -1.0346078283529194, '')],
#  [Text(-0.20378888554334487, 0.564331542737956, '61.031%'),
#   Text(0.20378888554334507, -0.5643315427379559, '38.969%')])

# %%
a= new_data['density']< new_data['density'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x236317beb90>,
# ...
#  [Text(-0.0010861263816185052, 1.099999463785998, ''),
#   Text(0.001086229371000633, -1.0999994636843027, '')],
#  [Text(-0.0005924325717919119, 0.5999997075196353, '50.031%'),
#   Text(0.000592488747818527, -0.5999997074641651, '49.969%')])

# %%
a= new_data['pH']< new_data['pH'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23631f07f10>,
# ...
#  [Text(-0.04668529570586137, 1.0990088640064994, ''),
#   Text(0.04668529570586123, -1.0990088640064994, '')],
#  [Text(-0.025464706748651655, 0.5994593803671815, '51.351%'),
#   Text(0.02546470674865158, -0.5994593803671815, '48.649%')])

# %%
a= new_data['sulphates']< new_data['sulphates'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23631f989d0>,
# ...
#  [Text(-0.3428095049994415, 1.0452184667723958, ''),
#   Text(0.3428096028598558, -1.045218434676249, '')],
#  [Text(-0.18698700272696808, 0.570119163694034, '60.088%'),
#   Text(0.1869870561053759, -0.5701191461870448, '39.912%')])

# %%
a= new_data['alcohol']< new_data['alcohol'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x2363200da50>,
# ...
#  [Text(-0.24658772383605812, 1.0720048947898289, ''),
#   Text(0.24658772383605823, -1.0720048947898289, '')],
#  [Text(-0.13450239481966805, 0.5847299426126339, '57.197%'),
#   Text(0.1345023948196681, -0.5847299426126339, '42.803%')])

# %%
a= new_data['quality']< new_data['quality'].mean()
plt.pie(a.value_counts(), autopct= '%.3f%%',frame= True)
# Out:
# ([<matplotlib.patches.Wedge at 0x23630f80d10>,
# ...
#  [Text(-0.1267832884893763, 1.0926692078391427, ''),
#   Text(0.12678328848937664, -1.0926692078391427, '')],
#  [Text(-0.06915452099420524, 0.5960013860940778, '53.677%'),
#   Text(0.06915452099420544, -0.5960013860940778, '46.323%')])

# %%
sns.histplot(data= new_data['fixed_acidity'], kde=True)
# Out:
# <Axes: xlabel='fixed_acidity', ylabel='Count'>

# %%
sns.histplot(data= new_data['volatile_acidity'], kde=True)
# Out:
# <Axes: xlabel='volatile_acidity', ylabel='Count'>

# %%
sns.histplot(data= new_data['citric_acid'], kde=True)
# Out:
# <Axes: xlabel='citric_acid', ylabel='Count'>

# %%
sns.histplot(data= new_data['residual_sugar'], kde=True)
# Out:
# <Axes: xlabel='residual_sugar', ylabel='Count'>

# %%
sns.histplot(data= new_data['chlorides'], kde=True)
# Out:
# <Axes: xlabel='chlorides', ylabel='Count'>

# %%
sns.histplot(data= new_data['free_sulphur_dioxide'], kde=True)
# Out:
# <Axes: xlabel='free_sulphur_dioxide', ylabel='Count'>

# %%
sns.histplot(data= new_data['total_sulphur_dioxide'], kde=True)
# Out:
# <Axes: xlabel='total_sulphur_dioxide', ylabel='Count'>

# %%
sns.histplot(data= new_data['density'], kde=True)
# Out:
# <Axes: xlabel='density', ylabel='Count'>

# %%
sns.histplot(data= new_data['pH'], kde=True)
# Out:
# <Axes: xlabel='pH', ylabel='Count'>

# %%
sns.histplot(data= new_data['sulphates'], kde=True)
# Out:
# <Axes: xlabel='sulphates', ylabel='Count'>

# %%
sns.histplot(data= new_data['alcohol'], kde=True)
# Out:
# <Axes: xlabel='alcohol', ylabel='Count'>

# %%
sns.histplot(data= new_data['quality'], kde=True)
# Out:
# <Axes: xlabel='quality', ylabel='Count'>

# %%
new_data['volatile_acidity'].describe
# Out:
# <bound method NDFrame.describe of 0       0.700
# 1       0.880
# 3       0.280
# 4       0.700
# 5       0.660
#         ...
# 1596    0.550
# 1597    0.510
# 1598    0.645
# 1599    0.310
# 1600    0.390
# Name: volatile_acidity, Length: 1591, dtype: float64>

# %%
new_data['citric_acid'].describe
# Out:
# <bound method NDFrame.describe of 0       0.00
# 1       0.00
# 3       0.56
# 4       0.00
# 5       0.00
#         ...
# 1596    0.10
# 1597    0.13
# 1598    0.12
# 1599    0.47
# 1600    0.44
# Name: citric_acid, Length: 1591, dtype: float64>

# %%
new_data['residual_sugar'].describe
# Out:
# <bound method NDFrame.describe of 0       1.9
# 1       2.6
# 3       1.9
# 4       1.9
# 5       1.8
#        ...
# 1596    2.2
# 1597    2.3
# 1598    2.0
# 1599    3.6
# 1600    2.6
# Name: residual_sugar, Length: 1591, dtype: float64>

# %%
new_data['chlorides'].describe
# Out:
# <bound method NDFrame.describe of 0       0.076
# 1       0.098
# 3       0.075
# 4       0.076
# 5       0.075
#         ...
# 1596    0.062
# 1597    0.076
# 1598    0.075
# 1599    0.067
# 1600    0.066
# Name: chlorides, Length: 1591, dtype: float64>

# %%
new_data['free_sulphur_dioxide'].describe
# Out:
# <bound method NDFrame.describe of 0       11.0
# 1       25.0
# 3       17.0
# 4       11.0
# 5       13.0
#         ...
# 1596    39.0
# 1597    29.0
# 1598    32.0
# 1599    18.0
# 1600    22.0
# Name: free_sulphur_dioxide, Length: 1591, dtype: float64>

# %%
new_data['total_sulphur_dioxide'].describe
# Out:
# <bound method NDFrame.describe of 0       34.0
# 1       67.0
# 3       60.0
# 4       34.0
# 5       40.0
#         ...
# 1596    51.0
# 1597    40.0
# 1598    44.0
# 1599    42.0
# 1600    48.0
# Name: total_sulphur_dioxide, Length: 1591, dtype: float64>

# %%
new_data['density'].describe
# Out:
# <bound method NDFrame.describe of 0       0.99780
# 1       0.99680
# 3       0.99800
# 4       0.99780
# 5       0.99780
#          ...
# 1596    0.99512
# 1597    0.99574
# 1598    0.99547
# 1599    0.99549
# 1600    0.99494
# Name: density, Length: 1591, dtype: float64>

# %%
new_data['pH'].describe
# Out:
# <bound method NDFrame.describe of 0       3.51
# 1       3.20
# 3       3.16
# 4       3.51
# 5       3.51
#         ...
# 1596    3.52
# 1597    3.42
# 1598    3.57
# 1599    3.39
# 1600    3.30
# Name: pH, Length: 1591, dtype: float64>

# %%
new_data['sulphates'].describe
# Out:
# <bound method NDFrame.describe of 0       0.56
# 1       0.68
# 3       0.58
# 4       0.56
# 5       0.56
#         ...
# 1596    0.76
# 1597    0.75
# 1598    0.71
# 1599    0.66
# 1600    0.84
# Name: sulphates, Length: 1591, dtype: float64>

# %%
new_data['alcohol'].describe
# Out:
# <bound method NDFrame.describe of 0        9.4
# 1        9.8
# 3        9.8
# 4        9.4
# 5        9.4
#         ...
# 1596    11.2
# 1597    11.0
# 1598    10.2
# 1599    11.0
# 1600    11.5
# Name: alcohol, Length: 1591, dtype: float64>

# %%
new_data['quality'].describe
# Out:
# <bound method NDFrame.describe of 0       5.0
# 1       5.0
# 3       6.0
# 4       5.0
# 5       5.0
#        ...
# 1596    6.0
# 1597    6.0
# 1598    5.0
# 1599    6.0
# 1600    6.0
# Name: quality, Length: 1591, dtype: float64>

# %% [markdown]
# I cleaned the data and removed Nan values aafter importing it into jupyter. I named it "new_data" to distinguish it from the original dataset. This helped me to find the mean with no errors since there's no mean for a null input. The mean value is important because instead of removing null values and losing some important data, we get an aproximate value inplace of the null. Mode method and Median method could have been used but the Mean method is most accurate.

# %% [markdown]
# ### 4- CORRELATION AND HEATMAP

# %%
data.corr()
# Out:
#                              ID  fixed_acidity  volatile_acidity  citric_acid  \
# ID                     1.000000      -0.267898         -0.009544    -0.153295
# fixed_acidity         -0.267898       1.000000         -0.255557     0.670856
# volatile_acidity      -0.009544      -0.255557          1.000000    -0.552910
# citric_acid           -0.153295       0.670856         -0.552910     1.000000
# residual_sugar        -0.031589       0.114595          0.001877     0.143517
# chlorides             -0.119130       0.093471          0.060747     0.203981
# free_sulphur_dioxide   0.091148      -0.152932         -0.010592    -0.061251
# total_sulphur_dioxide -0.113808      -0.113325          0.076247     0.036015
# density               -0.368725       0.667693          0.022753     0.364103
# pH                     0.135080      -0.682452          0.235183    -0.542639
# sulphates             -0.124243       0.182291         -0.261364     0.312839
# ...

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data.corr(), annot= True, cbar= True, cmap= 'BuPu')
# Out:
# <Axes: >

# %% [markdown]
# **The heatmap above shows that there is a significant correlation of the data among the columns.**
#
# For example;
#
# _There is positive correlation between:_
# 1. the density and the residual_sugar.
# 2. density and fixed_acidity.
# 3. fixed_acidity and citric_acid.
# 4. the free_sulfur_dioxide and total_sulfur_dioxide.
#
# _whereas the 3 below show a negative correlation:_
# 1. alcohol and density
# 2. fixed_acidity and pH
# 3. citric_acid and volatile_acidity
